# %% [markdown]
# # **Clase 2 - BeautifulSoup**

# %% [markdown]
# Dada la situación actual, se quiere recolectar información sobre el total de casos, muertes y personas recuperdas de COVID-19 en varios países alrededor del mundo. Para esto, se deberá scrapear (utilizando Beautiful Soup) la tabla presentada en la siguiente página: https://en.wikipedia.org/wiki/Template:2019%E2%80%9320_coronavirus_pandemic_data#covid19-container

# %%
import re
import urllib.request as urllib2
from bs4 import BeautifulSoup
import json
import requests
import pandas as pd

# %% [markdown]
# En esta actividad utilizaremos BeautifulSoup como herramienta para scrapear la pagina objetivo.

# %%
url = "https://en.wikipedia.org/wiki/Template:2019%E2%80%9320_coronavirus_pandemic_data"
html = requests.get(url).text.replace('\n', '')
soup = BeautifulSoup(html,'html.parser')

# %%
table = soup.find("table", id="thetable")
countries = table.tbody.find_all("tr")[2:]

# %%
data = []
for c in countries:
    row = {}

    if(c.get('class')): break
  
    #0. El primero siempre es la bandera
    #1. Nombre del país
    row['country'] = c.find_all('th')[1].text

    info = c.find_all('td')
    row['cases'] = info[0].text
    row['deaths'] = info[1].text
    row['ecov'] = info[2].text

    data.append(row)

# %%
df =  pd.DataFrame(data)
df.shape
# Out:
# (228, 4)

# %%
df.sample(5)
# Out:
#       country   cases deaths    ecov
# 27    Ireland  23,956  1,518  19,470
# 69   Cameroon   2,954    139   1,555
# 88   Slovenia   1,465    103     270
# 224      Saba       2      0       2
# 17     Mexico  45,032  4,767  30,451

# %% [markdown]
# Hasta este punto deberiamos tener la tabla recuperada.
# Quisieramos obtener ahora la información sobre la llegada del primer caso positivo a cada pais, este dato se puede obtener desde el infobox de la pagina relacionada a cada pais, como por ejemplo:
#
# https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Peru
#
# Arrival date:	6 March 2020 (1 month, 2 weeks and 4 days)
#
# Estos datos se deben guardar en columnas con nombre: arrival_date y time_since_arrival

# %%
countries[0]
# Out:
# <tr><th scope="row"><img alt="" class="thumbborder" data-file-height="650" data-file-width="1235" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" width="23"/></th><th scope="row"><a href="/wiki/COVID-19_pandemic_in_the_United_States" title="COVID-19 pandemic in the United States">United States</a><sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[e]</a></sup></th><td>1,472,743</td><td>88,199</td><td>259,834</td><td><sup class="reference" id="cite_ref-:1p3a_14-0"><a href="#cite_note-:1p3a-14">[9]</a></sup></td></tr>

# %%
base_url = "https://en.wikipedia.org"
date_ini = []
for c in countries:

    if(c.get('class')): break

    link = c.find_all('th')[1].a.get('href')
    url = base_url + link
    print(url)

    html = requests.get(url).text.replace('\n', '')
    country_soup = BeautifulSoup(html,'html.parser')
    info_table = country_soup.find("table", class_="infobox")
    try:
      trs = info_table.find_all('tr')
    except:
      date_ini.append('')
      continue

    fdate = ''
    for tr in trs:
        if(tr.th and tr.th.text=='Arrival date'):
            fdate = tr.td.text
    date_ini.append(fdate)
# Out:
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_S%C3%A3o_Tom%C3%A9_and_Pr%C3%ADncipe
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_South_Sudan
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Donetsk_People%27s_Republic
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Liberia
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Uganda
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Eswatini
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Faroe_Islands
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Myanmar
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Guam
# https://en.wikipedia.org/wiki/COVID-19_pandemic_on_cruise_ships#Costa_Atlantica
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Gibraltar
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Brunei
# https://en.wikipedia.org/wiki/COVID-19_pandemic_on_cruise_ships#Greg_Mortimer
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Bermuda
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Cambodia
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Mozambique
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Guyana
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Trinidad_and_Tobago
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Northern_Cyprus
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Yemen
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Aruba
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Mongolia
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Bahamas
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Monaco
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Cayman_Islands
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Barbados
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Liechtenstein
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Sint_Maarten
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Somaliland
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_United_States_Virgin_Islands
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Libya
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_French_Polynesia
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Malawi
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Syria
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Angola
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Macau
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Zimbabwe
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Eritrea
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_South_Ossetia
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Mauritania
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Nicaragua
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Antigua_and_Barbuda
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_East_Timor
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Botswana
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Gambia
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Grenada
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Bhutan
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Republic_of_Artsakh
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Laos
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Northern_Mariana_Islands
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Belize
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Fiji
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_New_Caledonia
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Saint_Lucia
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Abkhazia
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Saint_Vincent_and_the_Grenadines
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Cura%C3%A7ao
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Dominica
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Namibia
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Burundi
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Saint_Kitts_and_Nevis
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Falkland_Islands
# https://en.wikipedia.org/wiki/COVID-19_pandemic_on_cruise_ships#Zaandam
# https://en.wikipedia.org/wiki/COVID-19_pandemic_on_cruise_ships#Coral_Princess
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Turks_and_Caicos_Islands
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Vatican_City
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Comoros
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Greenland
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Montserrat
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Seychelles
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Suriname
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_British_Virgin_Islands
# https://en.wikipedia.org/wiki/COVID-19_pandemic_on_naval_ships#HNLMS_Dolfijn
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Papua_New_Guinea
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Anguilla
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Bonaire
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Saba
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Sint_Eustatius
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Lesotho
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Saint_Pierre_and_Miquelon

# %%
len(date_ini)
# Out:
# 228

# %%
df['Arrival date'] = date_ini
df.sample(5)
# Out:
#                country  ...                                    Arrival date
# 120         San Marino  ...  27 February 2020(2 months, 2 weeks and 5 days)
# 109              Niger  ...      19 March 2020(1 month, 3 weeks and 6 days)
# 189  Antigua & Barbuda  ...              10 March 2020(2 months and 6 days)
# 19            Pakistan  ...  26 February 2020(2 months, 2 weeks and 6 days)
# 176     Somaliland[ap]  ...      31 March 2020(1 month, 2 weeks and 2 days)
#
# [5 rows x 5 columns]

# %% [markdown]
# Finalmete, también se desea realizar una comparación entre el número de casos de COVID-19 contra el total de población del país, para esto puede ayudarse de la siguiente tabla.
#
# https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population
#
# Ese valor deberá anexarlo a la tabla final con el nombre population.
